# %%
# question1
for k in range(2000,3200):
    if k%7==0 and k%5!= 0:
        print(k,end=",")
        print("\n")
# Out:
# 2002,
#
# 2009,
#
# 2016,
#
# 2023,
#
# 2037,
#
# 2044,
#
# 2051,
#
# 2058,
#
# 2072,
#
# 2079,
#
# 2086,
#
# 2093,
#
# 2107,
#
# 2114,
#
# 2121,
#
# 2128,
#
# 2142,
#
# 2149,
#
# 2156,
#
# 2163,
#
# 2177,
#
# 2184,
#
# 2191,
#
# 2198,
#
# 2212,
#
# 2219,
#
# 2226,
#
# 2233,
#
# 2247,
#
# 2254,
#
# 2261,
#
# 2268,
#
# 2282,
#
# 2289,
#
# 2296,
#
# 2303,
#
# 2317,
#
# 2324,
#
# 2331,
#
# 2338,
#
# 2352,
#
# 2359,
#
# 2366,
#
# 2373,
#
# 2387,
#
# 2394,
#
# 2401,
#
# 2408,
#
# 2422,
#
# 2429,
#
# 2436,
#
# 2443,
#
# 2457,
#
# 2464,
#
# 2471,
#
# 2478,
#
# 2492,
#
# 2499,
#
# 2506,
#
# 2513,
#
# 2527,
#
# 2534,
#
# 2541,
#
# 2548,
#
# 2562,
#
# 2569,
#
# 2576,
#
# 2583,
#
# 2597,
#
# 2604,
#
# 2611,
#
# 2618,
#
# 2632,
#
# 2639,
#
# 2646,
#
# 2653,
#
# 2667,
#
# 2674,
#
# 2681,
#
# 2688,
#
# 2702,
#
# 2709,
#
# 2716,
#
# 2723,
#
# 2737,
#
# 2744,
#
# 2751,
#
# 2758,
#
# 2772,
#
# 2779,
#
# 2786,
#
# 2793,
#
# 2807,
#
# 2814,
#
# 2821,
#
# 2828,
#
# 2842,
#
# 2849,
#
# 2856,
#
# 2863,
#
# ...

# %%
# quetion 2
user_name = input("please enter your full name  ")
print('your name in reversed order is',user_name[::-1])
# Out:
# please enter your full name  Aastha Sharma
# your name in reversed order is amrahS ahtsaA

# %%
# quetion 3
import math
pi = math.pi #getting value of pi
Dmeter = 12
r = float(12/2) #converting dmeter into radius(r)
vol = float(4/3 * pi * (r**3))
print('volume of sphere is',vol)
# Out:
# volume of sphere is 904.7786842338603
